# %% [markdown]
# # Função para puxar os dados do Twitter

# %%
import base64
import requests
import json

# %%
client_key = 'RUpogiKVQVWc6ayCwJGNFtUpK'
client_secret = 'l6WYbRKHkneVKVCB6a8zm59KJKjxi8orsJE6X6UdcYCDbuNqJb'

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)
if auth_resp.status_code == 200:
    print('Conexão estabelecida com sucesso!')
# Out:
# Conexão estabelecida com sucesso!

# %%
access_token = auth_resp.json()['access_token']

# %%
def twitter_busca(search_params, access_token = access_token):
    search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
    }
    search_url = '{}1.1/search/tweets.json'.format(base_url)
    search_resp = requests.get(search_url, headers=search_headers, params=search_params)
    if search_resp.status_code == 200:
        print('Busca realizada com sucesso.')
        result = search_resp.json()
    return result

# %%
bancos_velhos = ['itaú', 'bradesco', 'santander', 'banco do brasil',
                      'banco original', 'banco inter']
bancos_novos = ['nubank', 'banco neon']

# %%
bancos_novos
# Out:
# ['nubank', 'banco neon']

# %%
search_params = {
    'q': bancos_novos,
    'result_type': 'recent',
    'count': 20
}

# %%
busca = twitter_busca(search_params)
# Out:
# Busca realizada com sucesso.

# %%
busca1 = twitter_busca(search_params)
# Out:
# Busca realizada com sucesso.

# %%
type(busca1)
# Out:
# dict

# %%
list(busca1.values())[0]
# Out:
# [{'created_at': 'Fri Aug 16 19:53:00 +0000 2019',
#   'id': 1162452216134983680,
#   'id_str': '1162452216134983680',
#   'text': 'Tanto tempo que sou cliente @nubank e nunca recebi um mimo pra valorizar a cliente maravilhosa que sou',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'nubank',
#      'name': 'Nubank',
#      'id': 2319390320,
#      'id_str': '2319390320',
#      'indices': [28, 35]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4829635461,
#    'id_str': '4829635461',
#    'name': 'Barbrinha',
#    'screen_name': 'barbaralimav',
# ...

# %%
for x in busca1['statuses']:
    print(x['user']['name'],':',x['text'] + '\n')
    print('---------')
# Out:
# Barbrinha : Tanto tempo que sou cliente @nubank e nunca recebi um mimo pra valorizar a cliente maravilhosa que sou
#
# ---------
# Nubank : @thiagosonic5 No Nubank, num primeiro momento, todo investimento em RDB renderá a 100% do CDI com liquidez diária.… https://t.co/EM7qlMKra5
#
# ---------
# William Amorim : Nubank libera cartão com função débito para todos os clientes da NuConta - https://t.co/I95J2jtdaR https://t.co/qX6Tajzywl
#
# ---------
# José Marcos : @nubank A oportunidade tá aí de me surpreender hehehe mas vou querer os adesivos sim 💜
#
# ---------
# Wesley Sapatão : @homemadesimon Eu pago tudo certinho e eles nunca me mandaram mimos
# Poxa @nubank pq não me mima?
#
# ---------
# Nubank : @yourskarlas Oie! Separamos aqui um link pra vc, dá uma olhadinha: https://t.co/AY3X58tsRf
#
# Lá explicamos tudo sobr… https://t.co/9tSkJ1woka
#
# ---------
# Rainhas Do Drible : @nubank @fefuza Eu acho que a Nubank deveria enviar a camisa, né? 😂💖
#
# ---------
# ...

# %%
tweet_data = twitter_busca(search_params)
# Out:
# Busca realizada com sucesso.

# %%
bancosnovosdata = []

# %%
for x in busca1['statuses']:
    bancosnovosdata[x] = [x['user']['name'],x['text']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3984a081556b> in <module>
#       1 for x in busca1['statuses']:
# ----> 2     bancosnovosdata[x] = [x['user']['name'],x['text']]
#
# TypeError: list indices must be integers or slices, not dict
